# %% [markdown]
# # Lab 5

# %% [markdown]
# Task 1

# %% [markdown]
# Write a program that will implement the following graph in python.

# %%
pip install networkx matplotlib
# Out:
# Requirement already satisfied: networkx in c:\users\muhammad faiq\appdata\local\programs\python\python310\lib\site-packages (3.3)
# Requirement already satisfied: matplotlib in c:\users\muhammad faiq\appdata\local\programs\python\python310\lib\site-packages (3.9.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\muhammad faiq\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\muhammad faiq\appdata\roaming\python\python310\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: numpy>=1.23 in c:\users\muhammad faiq\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (2.0.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\muhammad faiq\appdata\roaming\python\python310\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\muhammad faiq\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\muhammad faiq\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (4.53.1)
# Requirement already satisfied: pillow>=8 in c:\users\muhammad faiq\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\muhammad faiq\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\muhammad faiq\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: six>=1.5 in c:\users\muhammad faiq\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 24.2 is available.
# You should consider upgrading via the 'c:\Users\Muhammad Faiq\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
import networkx as nx
import matplotlib.pyplot as plt

graph = {
    0: [1, 4],
    1: [0, 2, 3, 4],
    2: [1, 3],
    3: [1, 2, 4],
    4: [0, 3]
}

G = nx.Graph()

for node in graph:
    for neighbor in graph[node]:
        G.add_edge(node, neighbor)

pos = nx.spring_layout(G)  # positions for all nodes
nx.draw(G, pos, with_labels=True, node_color='skyblue', node_size=2000, edge_color='k', font_size=15, font_weight='bold')

plt.title("Graph Visualization")
plt.show()

# %% [markdown]
# Task 2

# %%
from collections import deque

def bfs_find_target(graph, start, target):
    explored = set()
    frontier = deque([start])
    
    while frontier:
        node = frontier.popleft()
        print(f"Visiting {node}")
        
        if node == target:
            print(f"Found target {target}")
            return True
        
        explored.add(node)
        
        for neighbor in graph[node]:
            if neighbor not in explored:
                frontier.append(neighbor)
    
    print(f"Target {target} not found")
    return False

# Example graph represented as an adjacency list
graph = {
    'A': ['B', 'F', 'D', 'E'],
    'B': ['K', 'J'],
    'F': [],
    'D': ['G'],
    'E': ['C', 'H', 'I'],
    'K': ['N', 'M'],
    'J': [],
    'G': ['D'],
    'C': [],
    'H': [],
    'I': ['L'],
    'N': [],
    'M': [],
    'L': [],
}

# Starting BFS from vertex 'A' to find 'L'
print("BFS traversal to find 'L' starting from vertex 'A':")
bfs_find_target(graph, 'A', 'G')
# Out:
# BFS traversal to find 'L' starting from vertex 'A':
# Visiting A
# Visiting B
# Visiting F
# Visiting D
# Visiting E
# Visiting K
# Visiting J
# Visiting G
# Found target G
# True

# %% [markdown]
# Task 3

# %%
import heapq

class PriorityQueue:
    def __init__(self):
        self.elements = []
    
    def is_empty(self):
        return len(self.elements) == 0
    
    def put(self, item, priority):
        heapq.heappush(self.elements, (priority, item))
    
    def get(self):
        return heapq.heappop(self.elements)[1]


pq = PriorityQueue()

pq.put("task1", 3)
pq.put("task2", 1)
pq.put("task3", 2)

while not pq.is_empty():
    task = pq.get()
    print(task)
# Out:
# task2
# task3
# task1
